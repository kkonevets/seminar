# %% [markdown]
# # Linear regression

# %% [markdown]
# ![image.png](attachment:fe058bf0-892d-482b-af83-bab8f7085a4d.png)

# %% [markdown]
# ### Predicted value
# ### $\hat{y}(w,x) = w_0 + w_1x_1 + ... + w_px_p + \varepsilon$, where $\varepsilon \sim \mathcal{N}(0, \sigma^2)$ assume $\varepsilon_i$'s are IID (independently and identically distributed)
#
# ### $y_{i} \sim \mathcal{N}(w^Tx_{i}, \sigma^2)$
# ### Weights
# ![image.png](attachment:4cf1433e-2c5c-4b62-9b7e-d02079b4372a.png)
# ### Cost function
# ![image.png](attachment:4583b27f-9aec-4dfc-a596-e5c36f3bbb34.png)
# #### $X$ - матрица $[n \times (p+1)]$, each row is a dataset point, each row is a feature
# ## One dimension
# ![image.png](attachment:098dac5b-f428-46a0-97c8-957ce64f72ed.png) ![image.png](attachment:056ef9e1-9e68-4bfd-b02e-0aa70e10347f.png)
# ## Two dimensions
# ![image.png](attachment:8c39c3c8-d64e-4432-9d2c-2d0884546ed0.png)

# %% [markdown]
# ## Regularisation
# ![image.png](attachment:4b13d768-d408-41d8-9067-9f9848df4ca5.png)
#
# ![image.png](attachment:a47911dd-914b-4274-a26c-a21e46b70111.png)

# %% [markdown]
# ## Model evauation
# ### Minimize sum of squared residuals
# ![image.png](attachment:3e0b1fe0-f07f-4ef1-abdd-557ad680624f.png)
#
# ![image.png](attachment:6906338f-b845-4a56-934f-d274c0560b88.png)
#
# ### Coefficient of determination $R^2$
# Насколько наша модель лучше самой простой - mean of all points. Или по другому, насколько мала дисперсия ошибок по сравнению с простейшей моделью.
#
# ![image.png](attachment:2d5212ea-eae7-4754-bc32-73dde6a84ee5.png)
#
# ![image.png](attachment:e644ce28-3433-43ee-967b-d444b45a821d.png)
#
# ![image.png](attachment:1807e4c8-1346-4e92-92ca-ef6133f2cec2.png)
#
# ![image.png](attachment:2f53aa32-91c0-4fa7-9be5-09e32bc8b2f2.png)
#
# ![image.png](attachment:f42c97de-18c7-4aed-9e2d-5d984f9416af.png)
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination

# %% [markdown]
# # Logistic regression

# %% [markdown]
# #### Assume $y|x \sim Bernoulli(w)$ ![image.png](attachment:39f0a853-6d83-45b3-8ada-1331607aceb0.png) ![image.png](attachment:cbfab6b0-86c6-42b1-9f32-7a37b14a254a.png)

# %% [markdown]
# ## Binary Case
# #### We assume target $y_i$ takes values in the set ${\{0, 1\}}$. We predict the probability of a positive class with a sigmoid function
#
# ![image.png](attachment:0084994a-def3-4946-beb1-198ec3671b02.png)
# ### One dimension
# ![image.png](attachment:1eb6e767-d57f-497b-af85-5f155af23e24.png)
# ### Two dimensions
# ![image.png](attachment:c8158faf-7c71-44a3-ab7a-1f7b74efde09.png) ![image.png](attachment:b0a43f72-ae54-468e-9fd1-d4ee95d18ec9.png)

# %% [markdown]
# ## Likelihood function
# If events $A$ and $B$ are independent $P(AB) = P(A)P(B)$. So if $X_i$ are independent $P(X) = P(X_1X_2...X_3)=P(X_1)P(X_2) ... P(X_n)$
#
# ![image.png](attachment:eaec037a-f69b-4f0f-b4a2-5f32102610ef.png)
#
# #### Maximum likelihood estimation
# ![image.png](attachment:bea9705a-4322-4cb9-996e-6d9e74df516f.png)
#
# ![image.png](attachment:2f23cb19-e265-42c9-a676-6b43e57470e4.png)

# %% [markdown]
# ## Regularization
# ![image.png](attachment:6722b979-39f3-46bb-bd6c-92521ae585b1.png)
# ![image.png](attachment:e3289bc4-d46e-402b-937f-617a10a4e324.png)

# %% [markdown]
# ## Cost function
#
# ![image.png](attachment:8425162a-c627-4a8b-91d5-d092b888e286.png)
#
# ![image.png](attachment:f2b15a0c-1df0-4947-9d7b-824c6e945566.png)

# %% [markdown]
# ## Multinomial Case
# #### The binary case can be extended to $K$ classes leading to the multinomial logistic regression, $y_i \in 1,...,K$ using *Softmax* function:
# ![image.png](attachment:5e53e943-2b91-4407-9ed3-87c7abcab9e4.png)
# #### $X$  $[n \times (p+1)]$
# #### $W$  $[k \times (p+1)]$
# #### $X_i$ - $i$-th row of $X$, $W_i$ - $i$-th row of $W$
# ## Cost function
# ![image.png](attachment:f13f6605-3a81-401d-975e-a0b286131426.png)
#
# ![image.png](attachment:cf09743c-abb9-4e7b-bf5a-c0abdf200e6a.png)

# %% [markdown]
# ## Model evaluation
# ### Confusion matrix
# ![image.png](attachment:db1842c3-cce8-4dd2-896c-09526e6181bd.png) ![image.png](attachment:5a642d1d-2e58-4ac9-a23f-3d4722fb4db9.png)
# ![image.png](attachment:4698e421-f24d-4d7c-b7db-1fc0d4afafca.png)
#
# ![image.png](attachment:ec43aac8-fa6d-4576-8f65-b74ad408d9b9.png)
# ![image.png](attachment:91b4db79-4f4a-470f-a744-0581cdea17c6.png)
#
# ### Iris dataset
# ![image.png](attachment:675ff59c-3668-4d1d-8637-cbe14d2b6f9c.png)

# %% [markdown]
# # GLM Generalized lenear models

# %% [markdown]
# #### It can be shown that Gaussian and Bernoulli distributions belong to exponential family distributions defined as:
# ![image.png](attachment:a9dd57b7-8066-49dd-bd37-4eefdea67957.png)
#
# #### Bernoulli
# ![image.png](attachment:7bdbc933-d1ec-44ff-becd-658e80a2877d.png)
#
# #### Gaussian
# ![image.png](attachment:8e3d9878-18f6-40b4-8b4a-da8dc73be845.png)
#
# #### Poisson distribution also belongs to an exponential family

# %% [markdown]
# ## Constructing GLMs
#
# #### 1) ![image.png](attachment:d122633f-5b00-476b-999f-b2cc7b81782a.png)
#
# #### 2) learned hypothesis $h(x) = \tilde{y} = E[y|x; \eta]$
#
# #### 3) natural paramemrter $\eta$ and inputs $x$ are related linearly $\eta = \theta^Tx$
#
# ### Ordinary least squares (linear regression)
#
# ![image.png](attachment:d0e18fb4-1740-45a8-89ef-16849ec22ba1.png) because ![image.png](attachment:433f0c3a-382c-4f2c-9205-46963ac055f0.png)
#
# ### Logistic regression
#
# ![image.png](attachment:8d6b821c-67d0-4bf3-adfa-ae0d39ca28c7.png) because ![image.png](attachment:88f40279-4572-425e-a482-c518b77be9e6.png)

# %% [markdown]
# ## So what?
#
# #### This gives us a uniform framework for building linear models

# %% [markdown]
# # Solvers (optimisers)

# %% [markdown]
# ## Gradient
#
# ### Function gradient - points to the direction of function grouth, it's norm is an indicator of grouth speed
# ![image.png](attachment:9c2368b8-d86c-41ee-8490-449dbb3b83cc.png)
#
# ![image.png](attachment:2428e737-6e51-4daf-bde6-66eccf35548d.png)
#
# ### Gradient descent
# ![image.png](attachment:b0e2252d-5bf2-4204-8573-7ac39fe1b39a.png)
# ![image.png](attachment:0d2d9230-e7b9-490e-aecc-d6ac927727da.png)
# ![image.png](attachment:6132bc8d-1bb6-4037-a841-c0516701d09f.png)
#
# #### Efficiency of GD depends on initial value of $x$ and a step stgength $\alpha$:
#
# ![image.png](attachment:be65bf84-25d0-4fa8-8f54-94f26d846db7.png)
#
# ### Batch learning
# ##### If there is too much data to make a single full gradient step we can tack only a batch step
#
#
#
# ## SVD (Singular Value Decomposition) for linear regression
# In practice least squares Linear Regression has an analitical solution using SVD matrix decomposition, no need for optimisation.
#
# We assume that all points belong to a hyperplane $Ax=b$
#
# $A [n \times m]$
#
# 1) $n==m$
#
#    $x = A^{-1}b$
#
# 2) $n>m$
#
#     Infinitly many solutions  (2 points on a plain)
#
#     ![image.png](attachment:1dacca0a-6f70-4f35-93ed-96dc9dc677f2.png)
#
# 3) $n<m$
#
#     No Solutions (do 3 random points in 3D always belong to 2D? - linear regression case)
#
#    ![image.png](attachment:dbccd069-bbdb-49db-b414-1aa76592088b.png)
#
# ### SVD
#
# ![image.png](attachment:be52b389-fe02-4d58-be37-76c6a5d90895.png)
#
# ### $A = U \Sigma V^T$ for any $A$, where $U$ is $[m \times m]$, $\Sigma$ is $[m \times n]$ diagonal matrix which stores non-negative singular values ordered by relevance, $V$ is $[n \times n]$, $U$ and $V$ are orthogonal matrices
#
# ![image.png](attachment:af802fdd-163d-4743-91f0-e3ceaa9b0ed2.png)
#
# ![image.png](attachment:5630c3c6-6e9d-49b3-8c60-3866151be5e7.png)
#
# #### We can't invert $A$, what would be the best matrix $A+$ that, when multiplied by $A$, would come as close as possible to identity matrix $I$?
# #### We want ![image.png](attachment:9eef1a70-77d8-43fd-9b75-bf5400e64944.png)
# ![image.png](attachment:daaddb7d-462d-4089-8e14-89bce91bd359.png)
#
# ![image.png](attachment:2182d7c5-15ca-47dd-8bec-8b8440b2de23.png)
#
# #### Pseudo inverse $\hat{x} = UU^Tb$, where $U^Tb$ are the coordinates of $b$ with respect to the orthonormal basis $U$, because $U$ is orthogonal matix. And as $U$ is a rotation then $UU^Tb$ rotates $U^Tb$ to get projection of $x$ onto $span(X)$: ![image.png](attachment:c8a83a55-ec02-4623-bd66-8f6dc44023e9.png)
#
# #### Here $y$ is $b$:
#
# ![image.png](attachment:a2c14808-697e-4bf9-95be-d8368e784902.png)

# %% [markdown]
# ## Other optimisation methods (for logistic regression)
# ![image.png](attachment:882b383d-b1aa-468b-a123-272ea4885a2c.png)

# %% [markdown]
# ### Quasi-Newton methods
# #### Основаны на итеративном подсчете матрицы вторых производных, Гессиана, чтобы найти точку экстремума функции (минимум/максимум). Основное преимущество - не надо подбирать $\alpha$, а также меньше данных требую для обучения
#
# #### Разложение Тейлорва до второй степени:
#
# ![image.png](attachment:cd2aac2d-d9cb-436a-b278-64675cbf28da.png)
#
# ![image.png](attachment:14fbf69a-99f9-495c-871e-23ec89697b5b.png)
#
# ![image.png](attachment:5e817384-cf86-412d-a65e-dd276c774573.png)
#
# ![image.png](attachment:2d5228aa-01fa-4cc0-b5d8-cc12ef40bcd9.png)
#
# ![image.png](attachment:2cc8b189-a201-4704-bf3f-c727907516cc.png)
#
# ![image.png](attachment:c55ee4c1-313d-4e3f-a2cb-bbb365116e32.png)

# %% [markdown]
# # Backpropagation (auto-differentiation)

# %% [markdown]
# ## Task: compute $\nabla J(\theta)$ efficiently
#
# ![image.png](attachment:9dc47c0c-4e64-4e1b-9710-988433dc0ddb.png)
#
# ## Chain rule
#
# ![image.png](attachment:7a0c3d56-821d-4c56-97a0-50b38b228b0a.png)
#
# ![image.png](attachment:e3550b60-6a7f-46b4-8320-c94f75c36008.png)
#
# ![image.png](attachment:f6cd460b-3e3f-42c1-897c-8f141aee803e.png)
#
# ![image.png](attachment:19b18f63-1f3d-4317-b092-7162fa5701b3.png)
#
# ![image.png](attachment:1c0fde3a-dd48-42e3-b89a-1005255e736f.png)
#
# #### Abstractly write loss function $J$
#
# ![image.png](attachment:9528bf4b-8114-48d9-88c0-e629d110dc42.png)
#
# ![image.png](attachment:3fbf109b-e9e6-4496-8369-bc8a22e77a16.png)
#
# #### Backprop consists of 2 passes:
# #### 1) Forward pass  - compute $u^{[1]}...u^{[k]}$ and **save all intermidiate variables $u^{[i]}$s in memory**
# #### 2) Backward pass - compute derivatives w.r.t. intermidiate variables in a this backward order ![image.png](attachment:2cf54158-5c53-4e40-8ecd-e384f462110d.png)
#
# ![image.png](attachment:92bc5330-4f1d-4c55-89f6-7cb768696a9b.png)
#
# ![image.png](attachment:71328c1f-2022-44a8-8e02-41a70f808c89.png)
#
# ![image.png](attachment:406438b0-1457-4a8c-a94c-45e82e728445.png)
#
# ![image.png](attachment:f5bc4b8d-4e84-4152-978b-20246e0ffd14.png)
#
# ### The efficiency of backpropagation comes from the fact that each module has an efficiently implemented backward function.
# ### For example, backward function for $MM(z) = Wx+b$:
# ![image.png](attachment:74ab51db-2b40-4a5d-83ec-53895951a252.png)
#
# ![image.png](attachment:ed6fdb18-c8d7-48ee-b0b4-93ebc333cfbc.png)
#
# ![image.png](attachment:412b8903-f6c7-4fa3-bafe-2766bb1859ff.png)

# %% [markdown]
# ### Any linear model can be modeled as a neural network and backpropagation can be applied
#
# ![image.png](attachment:eb43356a-2691-4089-9b51-79c695968abb.png)  ![image.png](attachment:f4fd8baa-1d17-4d9a-b702-4796535472e5.png)
